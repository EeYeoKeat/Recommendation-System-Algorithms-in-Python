# %%
from psutil import virtual_memory
from tensorflow.python.client import device_lib
dev_sec = device_lib.list_local_devices()
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
  print(dev_sec[-1].physical_device_desc)
# Out:
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# !wget "http://files.grouplens.org/datasets/movielens/ml-100k.zip"
# !unzip ml-100k.zip
# !ls
# Out:
# --2020-11-04 01:26:05--  http://files.grouplens.org/datasets/movielens/ml-100k.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4924029 (4.7M) [application/zip]
# Saving to: ‘ml-100k.zip’
#
# ml-100k.zip         100%[===================>]   4.70M  12.3MB/s    in 0.4s
#
# 2020-11-04 01:26:06 (12.3 MB/s) - ‘ml-100k.zip’ saved [4924029/4924029]
#
# Archive:  ml-100k.zip
#    creating: ml-100k/
#   inflating: ml-100k/allbut.pl
#   inflating: ml-100k/mku.sh
#   inflating: ml-100k/README
#   inflating: ml-100k/u.data
#   inflating: ml-100k/u.genre
#   inflating: ml-100k/u.info
#   inflating: ml-100k/u.item
#   inflating: ml-100k/u.occupation
#   inflating: ml-100k/u.user
#   inflating: ml-100k/u1.base
#   inflating: ml-100k/u1.test
#   inflating: ml-100k/u2.base
#   inflating: ml-100k/u2.test
#   inflating: ml-100k/u3.base
#   inflating: ml-100k/u3.test
#   inflating: ml-100k/u4.base
#   inflating: ml-100k/u4.test
#   inflating: ml-100k/u5.base
#   inflating: ml-100k/u5.test
#   inflating: ml-100k/ua.base
#   inflating: ml-100k/ua.test
#   inflating: ml-100k/ub.base
#   inflating: ml-100k/ub.test
# ml-100k  ml-100k.zip  sample_data

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime, timedelta
import math
import random
from collections import deque

# %%
rating_data = pd.read_csv("ml-100k/ua.base", sep='\t',names="userId,movieId,rating,timestamp".split(",")) 
# need to sort the timestamp ascending?
rating_data
# Out:
#        userId  movieId  rating  timestamp
# 0           1        1       5  874965758
# 1           1        2       3  876893171
# 2           1        3       4  878542960
# 3           1        4       3  876893119
# 4           1        5       3  889751712
# ...       ...      ...     ...        ...
# 90565     943     1047       2  875502146
# 90566     943     1074       4  888640250
# 90567     943     1188       3  888640250
# 90568     943     1228       3  888640275
# 90569     943     1330       3  888692465
#
# [90570 rows x 4 columns]

# %%
user_list = rating_data['userId']
user_list = user_list.unique()
movie_rated_by_user = rating_data.groupby('movieId')['userId'].count().reset_index(name='userIdCount')
movie_rated_by_user = movie_rated_by_user.set_index('movieId')
movie_rated_by_user
# Out:
#          userIdCount
# movieId
# 1                392
# 2                121
# 3                 85
# 4                198
# 5                 79
# ...              ...
# 1678               1
# 1679               1
# 1680               1
# 1681               1
# 1682               1
#
# [1680 rows x 1 columns]

# %%
item_column_name = "movieId,movie_title,release_date,video_release_date,IMDb_URL,unknown,Action,Adventure,Animation,Children,Comedy,Crime,Documentary,Drama,Fantasy,Film-Noir,Horror,Musical,Mystery,Romance,Sci-Fi,Thriller,War,Western"
item = pd.read_csv("ml-100k/u.item",sep='|',names=item_column_name.split(","),encoding='latin-1')
col_to_removed = ['movie_title', 'release_date', 'video_release_date', 'IMDb_URL']
clear_item = item.drop(col_to_removed, axis=1).set_index('movieId')

# the number of the kinds of topics in the whole recommendation system.
N = len(clear_item.columns)

# sum up the genre for each movieId
genre_num = clear_item.sum(axis = 1)

# group table by index and creates a dict with lists of clear_item as values
df_dict = dict(list(clear_item.groupby(clear_item.index)))

# Gather all the genres that related to all movies respectively
movieid = []
genre_list = []

for u, v in df_dict.items():
    check = v.columns[(v == 1).any()]
    if len(check) > 0:
      movieid.append(u)
      genre_list.append(check.to_list())

d = {'movieId' : movieid, 'Genres' : genre_list}

# compile in DataFrame
genre_list_by_movieid = pd.DataFrame(d)
genre_list_by_movieid.set_index('movieId', inplace=True)
genre_list_by_movieid
# Out:
#                                 Genres
# movieId
# 1        [Animation, Children, Comedy]
# 2        [Action, Adventure, Thriller]
# 3                           [Thriller]
# 4              [Action, Comedy, Drama]
# 5             [Crime, Drama, Thriller]
# ...                                ...
# 1678                           [Drama]
# 1679               [Romance, Thriller]
# 1680                  [Drama, Romance]
# 1681                          [Comedy]
# 1682                           [Drama]
#
# [1682 rows x 1 columns]

# %%
clear_item
# Out:
#          unknown  Action  Adventure  Animation  ...  Sci-Fi  Thriller  War  Western
# movieId                                         ...
# 1              0       0          0          1  ...       0         0    0        0
# 2              0       1          1          0  ...       0         1    0        0
# 3              0       0          0          0  ...       0         1    0        0
# 4              0       1          0          0  ...       0         0    0        0
# 5              0       0          0          0  ...       0         1    0        0
# ...          ...     ...        ...        ...  ...     ...       ...  ...      ...
# 1678           0       0          0          0  ...       0         0    0        0
# 1679           0       0          0          0  ...       0         1    0        0
# 1680           0       0          0          0  ...       0         0    0        0
# 1681           0       0          0          0  ...       0         0    0        0
# 1682           0       0          0          0  ...       0         0    0        0
#
# [1682 rows x 19 columns]

# %%
rating_genre = rating_data.join(clear_item, on='movieId')
rating_genre
# Out:
#        userId  movieId  rating  timestamp  ...  Sci-Fi  Thriller  War  Western
# 0           1        1       5  874965758  ...       0         0    0        0
# 1           1        2       3  876893171  ...       0         1    0        0
# 2           1        3       4  878542960  ...       0         1    0        0
# 3           1        4       3  876893119  ...       0         0    0        0
# 4           1        5       3  889751712  ...       0         1    0        0
# ...       ...      ...     ...        ...  ...     ...       ...  ...      ...
# 90565     943     1047       2  875502146  ...       0         0    0        0
# 90566     943     1074       4  888640250  ...       0         0    0        0
# 90567     943     1188       3  888640250  ...       0         0    0        1
# 90568     943     1228       3  888640275  ...       0         0    0        0
# 90569     943     1330       3  888692465  ...       0         0    0        0
#
# [90570 rows x 23 columns]

# %%
user_data = pd.read_csv("ml-100k/u.user", sep='|',names="userId,age,gender,occupation,zipcode".split(",")).set_index('userId') 
user_data
# Out:
#         age gender     occupation zipcode
# userId
# 1        24      M     technician   85711
# 2        53      F          other   94043
# 3        23      M         writer   32067
# 4        24      M     technician   43537
# 5        33      F          other   15213
# ...     ...    ...            ...     ...
# 939      26      F        student   33319
# 940      32      M  administrator   02215
# 941      20      M        student   97229
# 942      48      F      librarian   78209
# 943      22      M        student   77841
#
# [943 rows x 4 columns]

# %%
raw = rating_genre.join(user_data, on='userId')
raw.head()
# Out:
#    userId  movieId  rating  timestamp  ...  age  gender  occupation  zipcode
# 0       1        1       5  874965758  ...   24       M  technician    85711
# 1       1        2       3  876893171  ...   24       M  technician    85711
# 2       1        3       4  878542960  ...   24       M  technician    85711
# 3       1        4       3  876893119  ...   24       M  technician    85711
# 4       1        5       3  889751712  ...   24       M  technician    85711
#
# [5 rows x 27 columns]

# %%
# All categorical columns
object_cols = [col for col in raw.columns if raw[col].dtype == "object"]
object_cols
# Out:
# ['gender', 'occupation', 'zipcode']

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading https://files.pythonhosted.org/packages/44/57/fcef41c248701ee62e8325026b90c432adea35555cbc870aff9cfba23727/category_encoders-2.2.2-py2.py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 3.6MB/s
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.1.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.0->category_encoders) (0.17.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.2.2

# %%
import category_encoders as ce
encoder = LabelEncoder()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
encoder = ce.BackwardDifferenceEncoder(cols=['gender', 'occupation'])
encoded_raw = encoder.fit_transform(raw)
encoded_raw
# Out:
# /usr/local/lib/python3.6/dist-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#        intercept  userId  movieId  ...  occupation_18  occupation_19  zipcode
# 0              1       1        1  ...      -0.095238      -0.047619    85711
# 1              1       1        2  ...      -0.095238      -0.047619    85711
# 2              1       1        3  ...      -0.095238      -0.047619    85711
# 3              1       1        4  ...      -0.095238      -0.047619    85711
# 4              1       1        5  ...      -0.095238      -0.047619    85711
# ...          ...     ...      ...  ...            ...            ...      ...
# 90565          1     943     1047  ...      -0.095238      -0.047619    77841
# 90566          1     943     1074  ...      -0.095238      -0.047619    77841
# 90567          1     943     1188  ...      -0.095238      -0.047619    77841
# 90568          1     943     1228  ...      -0.095238      -0.047619    77841
# 90569          1     943     1330  ...      -0.095238      -0.047619    77841
#
# [90570 rows x 47 columns]

# %%
scaler = MinMaxScaler() 
encoded_raw['scaled_age'] = scaler.fit_transform(encoded_raw[['age']])
encoded_raw
# Out:
#        intercept  userId  movieId  ...  occupation_19  zipcode  scaled_age
# 0              1       1        1  ...      -0.047619    85711    0.257576
# 1              1       1        2  ...      -0.047619    85711    0.257576
# 2              1       1        3  ...      -0.047619    85711    0.257576
# 3              1       1        4  ...      -0.047619    85711    0.257576
# 4              1       1        5  ...      -0.047619    85711    0.257576
# ...          ...     ...      ...  ...            ...      ...         ...
# 90565          1     943     1047  ...      -0.047619    77841    0.227273
# 90566          1     943     1074  ...      -0.047619    77841    0.227273
# 90567          1     943     1188  ...      -0.047619    77841    0.227273
# 90568          1     943     1228  ...      -0.047619    77841    0.227273
# 90569          1     943     1330  ...      -0.047619    77841    0.227273
#
# [90570 rows x 48 columns]

# %%
drop_col = ['userId','intercept','movieId','timestamp','age','zipcode']
train_data = encoded_raw.drop(drop_col, axis=1)
train_data
# Out:
#        rating  unknown  Action  ...  occupation_18  occupation_19  scaled_age
# 0           5        0       0  ...      -0.095238      -0.047619    0.257576
# 1           3        0       1  ...      -0.095238      -0.047619    0.257576
# 2           4        0       0  ...      -0.095238      -0.047619    0.257576
# 3           3        0       1  ...      -0.095238      -0.047619    0.257576
# 4           3        0       0  ...      -0.095238      -0.047619    0.257576
# ...       ...      ...     ...  ...            ...            ...         ...
# 90565       2        0       0  ...      -0.095238      -0.047619    0.227273
# 90566       4        0       0  ...      -0.095238      -0.047619    0.227273
# 90567       3        0       1  ...      -0.095238      -0.047619    0.227273
# 90568       3        0       1  ...      -0.095238      -0.047619    0.227273
# 90569       3        0       0  ...      -0.095238      -0.047619    0.227273
#
# [90570 rows x 42 columns]

# %% [markdown]
# # **Extra**

# %%
def truncat_user(user_id):
    temp = raw[raw['userId'] == user_id]
    n = len(temp)
    print('Extract done...\n',n)
    return temp

# %%
# Further group numerical predictors such as "age" or "hours-per-week" to gain more insight!
# Group the "age" column
age_group = []
for age in income_df["age"]:
    if age < 25:
        age_group.append("<25")
    elif 25 <= age <= 34:
        age_group.append("25-34")
    elif 34 < age <= 44:
        age_group.append("35-44")
    elif 44 < age <= 54:
        age_group.append("45-54")
    elif 54 < age <= 65:
        age_group.append("55-64")
    else:
        age_group.append("65 and over")
new_income_df = income_df.copy()
new_income_df["age_group"] = age_group
del new_income_df["age"]

# %%
def convert(data, num_users, num_movies):
    ''' Making a User-Movie-Matrix'''
    
    new_data=[]
    
    for id_user in range(1, num_users+1):
        
        id_movie=data[:,1][data[:,0]==id_user]
        id_rating=data[:,2][data[:,0]==id_user]
        ratings=np.zeros(num_movies, dtype=np.uint32)
        ratings[id_movie-1]=id_rating
        if sum(ratings)==0:
            continue
        new_data.append(ratings)

        del id_movie
        del id_rating
        del ratings
        
    return new_data

# %%
def get_dataset():
    ''' For each train.dat and test.dat making a User-Movie-Matrix'''
    
    training_set=pd.read_csv("ml-100k/ua.base", sep='\t', header=None, engine='python', encoding='latin-1')
    training_set=np.array(training_set, dtype=np.uint32)
    
    test_set=pd.read_csv("ml-100k/ua.test", sep='\t', header=None, engine='python', encoding='latin-1')
    test_set=np.array(test_set, dtype=np.uint32)
    
      
    num_users=int(max(max(training_set[:,0]), max(test_set[:,0])))
    num_movies=int(max(max(training_set[:,1]), max(test_set[:,1])))

    training_set=convert(training_set,num_users, num_movies)
    test_set=convert(test_set,num_users, num_movies)
    
    return training_set, test_set

# %%
nani= get_dataset()
nani

# %%
training_set=pd.read_csv("ml-100k/ua.base", sep='\t', header=None, engine='python', encoding='latin-1')
training_set=np.array(training_set, dtype=np.uint32)
training_set
# Out:
# array([[        1,         1,         5, 874965758],
#        [        1,         2,         3, 876893171],
#        [        1,         3,         4, 878542960],
#        ...,
#        [      943,      1188,         3, 888640250],
#        [      943,      1228,         3, 888640275],
#        [      943,      1330,         3, 888692465]], dtype=uint32)

# %%
test_set=pd.read_csv("ml-100k/ua.test", sep='\t', header=None, engine='python', encoding='latin-1')
test_set=np.array(test_set, dtype=np.uint32)

# %%
test_set
# Out:
# array([[        1,        20,         4, 887431883],
#        [        1,        33,         4, 878542699],
#        [        1,        61,         4, 878542420],
#        ...,
#        [      943,       570,         1, 888640125],
#        [      943,       808,         4, 888639868],
#        [      943,      1067,         2, 875501756]], dtype=uint32)

# %%
num_users=int(max(max(training_set[:,0]), max(test_set[:,0])))
num_movies=int(max(max(training_set[:,1]), max(test_set[:,1])))

# %%
training_set=convert(training_set,num_users, num_movies)
test_set=convert(test_set,num_users, num_movies)

# %%
training_set
# Out:
# [array([5, 3, 4, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([1, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 5, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 1, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 2, 1, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 4, 5, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([1, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 2, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 5, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 5, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 4, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 1, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 1, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 2, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 3, 2, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 2, 2, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 3, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 4, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 1, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([1, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 1, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 5, 3, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 4, 3, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 1, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([1, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 3, 2, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 4, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([1, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 1, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 5, 5, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([5, 3, 5, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 1, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 5, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 1, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 2, 5, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 3, 3, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 5, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 5, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 5, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 5, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([1, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 3, 5, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 1, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 1, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([2, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 2, 1, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 5, ..., 0, 0, 0], dtype=uint32),
#  array([5, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 4, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 1, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([1, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 1, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 2, ..., 0, 0, 0], dtype=uint32),
#  array([2, 5, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 5, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 1, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 5, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 2, 0, 0], dtype=uint32),
#  array([5, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([1, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 2, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 1, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 4, 3, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 3, 4, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 0, ..., 0, 3, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 2, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 3, 3, ..., 0, 0, 3], dtype=uint32),
#  array([3, 0, 1, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([5, 3, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([2, 4, 0, ..., 0, 0, 0], dtype=uint32),
#  array([3, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 4, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([4, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([5, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint32),
#  array([0, 5, 0, ..., 0, 0, 0], dtype=uint32)]
